# %% [markdown]
# # LIBRARY MANAGEMENT SYSTEM

# %% [markdown]
# ![ChatGPT Image Sep 26, 2026, 01_19_39 AM.png](attachment:4b18e794-cbf8-4b02-8e89-4c956d16ca02.png)

# %%
import json
try:
    with open("library.json", "r") as file:
        library = json.load(file)
except FileNotFoundError:
    library = []

print(library)
# Out:
# []

# %%
def save_records():
    with open("library.json", "w") as file:
        json.dump(library, file, indent=4)

# %%
save_records()

# %%
def add_book():
    book_id = int(input("Enter book id: "))
    title = input("Enter title of the book :")
    author = input("Enter author's name: ")

    book = {
        "id" : book_id ,
        "title" : title ,
        "autthor" : author , 
        "available" : True 
    
    }
    library.append(book)
    save_records()

    print("Book added successfully ! ")

# %%
add_book()
# Out:
# Enter book id:  1
# Enter title of the book : Python Basics
# Enter author's name:  John Smith
# Book added successfully !

# %%
add_book()
# Out:
# Enter book id:  2
# Enter title of the book : The Alchemist
# Enter author's name:  Paulo Coelho
# Book added successfully !

# %%
add_book()
# Out:
# Enter book id:  3
# Enter title of the book : The Midnight Library
# Enter author's name:  Matt Haig
# Book added successfully !

# %%
add_book()
# Out:
# Enter book id:  4
# Enter title of the book : The Kite Runner
# Enter author's name:  Khaled Hosseini
# Book added successfully !

# %%
add_book()
# Out:
# Enter book id:  5
# Enter title of the book : The Seven Husbands of Evelyn Hugo
# Enter author's name:  Taylor Jenkins Reid
# Book added successfully !

# %%
add_book()
# Out:
# Enter book id:  6
# Enter title of the book : To Kill a Mockingbird
# Enter author's name:  Harper Lee
# Book added successfully !

# %%
add_book()
# Out:
# Enter book id:  7
# Enter title of the book : The Hunger Games
# Enter author's name:  Suzzanne Collins
# Book added successfully !

# %%
add_book()
# Out:
# Enter book id:  8
# Enter title of the book : The Fault in Our Stars
# Enter author's name:  John Green
# Book added successfully !

# %%
add_book()
# Out:
# Enter book id:  9
# Enter title of the book : The Book Thief
# Enter author's name:  Markus Zusak
# Book added successfully !

# %%
add_book()
# Out:
# Enter book id:  10
# Enter title of the book : Pride and Prejudice
# Enter author's name:  Stephen Chbosky
# Book added successfully !

# %%
print(library)
# Out:
# [{'id': 1, 'title': 'Python Basics', 'autthor': 'John Smith', 'available': True}, {'id': 2, 'title': 'The Alchemist', 'autthor': 'Paulo Coelho', 'available': True}, {'id': 3, 'title': 'The Midnight Library', 'autthor': 'Matt Haig', 'available': True}, {'id': 4, 'title': 'The Kite Runner', 'autthor': 'Khaled Hosseini', 'available': True}, {'id': 5, 'title': 'The Seven Husbands of Evelyn Hugo', 'autthor': 'Taylor Jenkins Reid ', 'available': True}, {'id': 6, 'title': 'To Kill a Mockingbird', 'autthor': 'Harper Lee', 'available': True}, {'id': 7, 'title': 'The Hunger Games', 'autthor': 'Suzzanne Collins', 'available': True}, {'id': 8, 'title': 'The Fault in Our Stars', 'autthor': 'John Green', 'available': True}, {'id': 9, 'title': 'The Book Thief', 'autthor': 'Markus Zusak', 'available': True}, {'id': 10, 'title': 'Pride and Prejudice', 'autthor': 'Stephen Chbosky', 'available': True}]

# %%
def display_available_books():
    print("\n Available books")
    print("-" * 60)
    for book in library:
        if book["available"]:
            print(f"ID: {book['id']}")
            print(f"Title: {book['title']}")
            print(f"Author: {book['author']}")
            print("-" * 60)

# %%
display_available_books()
# Out:
#  Available books
# ------------------------------------------------------------
# ID: 1
# Title: Python Basics
# Author: John Smith
# ------------------------------------------------------------
# ID: 2
# Title: The Alchemist
# Author: Paulo Coelho
# ------------------------------------------------------------
# ID: 3
# Title: The Midnight Library
# Author: Matt Haig
# ------------------------------------------------------------
# ID: 4
# Title: The Kite Runner
# Author: Khaled Hosseini
# ------------------------------------------------------------
# ID: 5
# Title: The Seven Husbands of Evelyn Hugo
# Author: Taylor Jenkins Reid
# ------------------------------------------------------------
# ID: 6
# Title: To Kill a Mockingbird
# Author: Harper Lee
# ------------------------------------------------------------
# ID: 7
# Title: The Hunger Games
# Author: Suzzanne Collins
# ------------------------------------------------------------
# ID: 8
# Title: The Fault in Our Stars
# ...

# %%
print(library[0])
# Out:
# {'id': 1, 'title': 'Python Basics', 'autthor': 'John Smith', 'available': True}

# %%
for book in library:
    if "autthor" in book:
        book["author"] = book.pop("autthor")

save_records()

# %%
print(library[0])
# Out:
# {'id': 1, 'title': 'Python Basics', 'available': True, 'author': 'John Smith'}

# %%
display_available_books()
# Out:
#  Available books
# ------------------------------------------------------------
# ID: 1
# Title: Python Basics
# Author: John Smith
# ------------------------------------------------------------
# ID: 2
# Title: The Alchemist
# Author: Paulo Coelho
# ------------------------------------------------------------
# ID: 3
# Title: The Midnight Library
# Author: Matt Haig
# ------------------------------------------------------------
# ID: 4
# Title: The Kite Runner
# Author: Khaled Hosseini
# ------------------------------------------------------------
# ID: 5
# Title: The Seven Husbands of Evelyn Hugo
# Author: Taylor Jenkins Reid
# ------------------------------------------------------------
# ID: 6
# Title: To Kill a Mockingbird
# Author: Harper Lee
# ------------------------------------------------------------
# ID: 7
# Title: The Hunger Games
# Author: Suzzanne Collins
# ------------------------------------------------------------
# ID: 8
# Title: The Fault in Our Stars
# ...

# %%
def search_book(): 
    search_title = input("Enter name of the book you want to search :")
    found = False

    for book in library:
        if search_title.lower() in book["title"].lower():
            print( "Book found !")
            print(f"ID: {book['id']}")
            print(f"Title: {book['title']}")
            print(f"Author: {book['author']}")
            
            if book["available"]:
                print("Status: Available")
            else:
                print("Status: Issued")

            found = True

    if not found:
        print("Book not found.")

# %%
search_book()
# Out:
# Enter name of the book you want to search : The Fault in Our stars
# Book found !
# ID: 8
# Title: The Fault in Our Stars
# Author: John Green
# Status: Available

# %%
search_book()
# Out:
# Enter name of the book you want to search : Hello Pytgon world
# Book not found.

# %%
def issue_book():
    book_id = int(input("Enter book ID to issue: "))

    for book in library:
        if book["id"] == book_id: 
            if book["available"]: 
                book["available"] = False
                save_records()
                print ("Book issued successfully!")
            else:
                print ("Book is already issued!" )
                      
            return

    print("Book not found!")

# %%
issue_book()
# Out:
# Enter book ID to issue:  7
# Book issued successfully!

# %%
issue_book()
# Out:
# Enter book ID to issue:  8
# Book issued successfully!

# %%
issue_book()
# Out:
# Enter book ID to issue:  10
# Book issued successfully!

# %%
issue_book()
# Out:
# Enter book ID to issue:  12
# Book not found!

# %%
def return_book(): 
    book_id = int(input("Enter book id to return:"))

    for book in library: 
        if book["id"] == book_id: 
            if not book ["available"]: 
                book["available"] = True
                save_records()
                print("Book returned successfully!")
            else: 
                print("Book is already available!")

            return

    print("Book not found!")

# %%
return_book()
# Out:
# Enter book id to return: 7
# Book returned successfully!

# %%
return_book()
# Out:
# Enter book id to return: 8
# Book returned successfully!

# %%
return_book()
# Out:
# Enter book id to return: 12
# Book not found!

# %%
save_records()
print("Records saved successfully!")
# Out:
# Records saved successfully!

# %%
def library_management_system():
    while True:
        print("\n===== LIBRARY MANAGEMENT SYSTEM =====")
        print("1. Add Book")
        print("2. Search Book")
        print("3. Issue Book")
        print("4. Return Book")
        print("5. Display Available Books")
        print("6. Save Records")
        print("7. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            add_book()

        elif choice == "2":
            search_book()

        elif choice == "3":
            issue_book()

        elif choice == "4":
            return_book()

        elif choice == "5":
            display_available_books()

        elif choice == "6":
            save_records()
            print("Records saved successfully!")

        elif choice == "7":
            save_records()
            print("Thank you for using the Library Management System!")
            break

        else:
            print("Invalid choice. Please try again.")

# %%
library_management_system()
# Out:
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. Search Book
# 3. Issue Book
# 4. Return Book
# 5. Display Available Books
# 6. Save Records
# 7. Exit
# Enter your choice:  7
# Thank you for using the Library Management System!

# %%
library_management_system()
# Out:
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. Search Book
# 3. Issue Book
# 4. Return Book
# 5. Display Available Books
# 6. Save Records
# 7. Exit
# Enter your choice:  2
# Enter name of the book you want to search : The Hunger Games
# Book found !
# ID: 7
# Title: The Hunger Games
# Author: Suzzanne Collins
# Status: Available
# Book found !
# ID: 7
# Title: The Hunger Games
# Author: Suzzane Collins
# Status: Available
#
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. Search Book
# 3. Issue Book
# 4. Return Book
# 5. Display Available Books
# 6. Save Records
# 7. Exit
# Enter your choice:  2
# Enter name of the book you want to search : The fault in Our starts
# Book not found.
#
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. Search Book
# 3. Issue Book
# 4. Return Book
# 5. Display Available Books
# 6. Save Records
# 7. Exit
# Enter your choice:  8
# Invalid choice. Please try again.
#
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# ...

# %%
for book in library:
    print(book)
# Out:
# {'id': 1, 'title': 'Python Basics', 'available': True, 'author': 'John Smith'}
# {'id': 2, 'title': 'The Alchemist', 'available': True, 'author': 'Paulo Coelho'}
# {'id': 3, 'title': 'The Midnight Library', 'available': True, 'author': 'Matt Haig'}
# {'id': 4, 'title': 'The Kite Runner', 'available': True, 'author': 'Khaled Hosseini'}
# {'id': 5, 'title': 'The Seven Husbands of Evelyn Hugo', 'available': True, 'author': 'Taylor Jenkins Reid '}
# {'id': 6, 'title': 'To Kill a Mockingbird', 'available': True, 'author': 'Harper Lee'}
# {'id': 7, 'title': 'The Hunger Games', 'available': True, 'author': 'Suzzanne Collins'}
# {'id': 8, 'title': 'The Fault in Our Stars', 'available': True, 'author': 'John Green'}
# {'id': 9, 'title': 'The Book Thief', 'available': True, 'author': 'Markus Zusak'}
# {'id': 10, 'title': 'Pride and Prejudice', 'available': False, 'author': 'Stephen Chbosky'}
# {'id': 7, 'title': 'The Hunger Games', 'available': True, 'author': 'Suzzane Collins'}

# %%
library_management_system()
# Out:
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. Search Book
# 3. Issue Book
# 4. Return Book
# 5. Display Available Books
# 6. Save Records
# 7. Exit
# Enter your choice:  2
# Enter name of the book you want to search : The Hunger Games
# Book found !
# ID: 7
# Title: The Hunger Games
# Author: Suzzanne Collins
# Status: Available
#
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. Search Book
# 3. Issue Book
# 4. Return Book
# 5. Display Available Books
# 6. Save Records
# 7. Exit
# Enter your choice:  7
# Thank you for using the Library Management System!
